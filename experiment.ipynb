# %%
import pandas as pd
import numpy as np

# df = pd.read_csv('./model/final.csv', encoding='utf-8')
df = pd.read_csv('./model/transpose.csv', encoding='utf-8')
# Read headers
df.to_json()
# Out:
# '{"Note;f0;L;d;\\u03c1;T0;Ru;Rv;R\\u03c6;\\u03b7u;\\u03b7v;\\u03b7\\u03c6;p;xH;MH;KH;RH;x0;y0":{"0":"C1;32.78;4.647;1.258;7850;905;5.0 \\u00d7 10\\u221203;5.0 \\u00d7 10\\u221201;5.0 \\u00d7 10\\u221203;1.6 \\u00d7 10\\u221209;1.0 \\u00d7 10\\u221209;1.6 \\u00d7 10\\u221209;2.310;0.558;10.95;7.160 \\u00d7 1007;2.434 \\u00d7 1005;0.40;1.69","1":"Cd1;34.73;4.400;1.281;7850;945;1.0 \\u00d7 10\\u221202;5.0 \\u00d7 10\\u221201;1.0 \\u00d7 10\\u221202;1.7 \\u00d7 10\\u221209;1.0 \\u00d7 10\\u221209;1.7 \\u00d7 10\\u221209;2.305;0.528;10.89;8.091 \\u00d7 1007;2.487 \\u00d7 1005;0.42;1.67","2":"D1;36.79;4.167;1.268;7850;932;1.5 \\u00d7 10\\u221202;5.0 \\u00d7 10\\u221201;1.5 \\u00d7 10\\u221202;1.7 \\u00d7 10\\u221209;1.0 \\u00d7 10\\u221209;1.7 \\u00d7 10\\u221209;2.300;0.500;10.83;9.143 \\u00d7 1007;2.542 \\u00d7 1005;0.44;1.65","3":"Dd1;38.98;3.945;1.237;7850;892;2.0 \\u00d7 10\\u221202;5.0 \\u00d7 10\\u221201;2.0 \\u00d7 10\\u221202;1.7 \\u00d7 10\\u221209;1.0 \\u00d7 10\\u221209;1.7 \\u
# ...
